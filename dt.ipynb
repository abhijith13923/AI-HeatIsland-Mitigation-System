# %%
import joblib

model = joblib.load('uhi_model.pkl')

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

plt.figure(figsize=(15,20))
plot_tree(model)
# Out:
# [Text(0.3333333333333333, 0.875, 'x[5] <= 0.995\ngini = 0.365\nsamples = 960\nvalue = [753, 116, 63, 28]'),
#  Text(0.16666666666666666, 0.625, 'gini = 0.0\nsamples = 753\nvalue = [753, 0, 0, 0]'),
#  Text(0.25, 0.75, 'True  '),
#  Text(0.5, 0.625, 'x[5] <= 2.51\ngini = 0.575\nsamples = 207\nvalue = [0.0, 116.0, 63.0, 28.0]'),
#  Text(0.41666666666666663, 0.75, '  False'),
#  Text(0.3333333333333333, 0.375, 'gini = 0.0\nsamples = 116\nvalue = [0, 116, 0, 0]'),
#  Text(0.6666666666666666, 0.375, 'x[5] <= 4.535\ngini = 0.426\nsamples = 91\nvalue = [0, 0, 63, 28]'),
#  Text(0.5, 0.125, 'gini = 0.0\nsamples = 63\nvalue = [0, 0, 63, 0]'),
#  Text(0.8333333333333334, 0.125, 'gini = 0.0\nsamples = 28\nvalue = [0, 0, 0, 28]')]
